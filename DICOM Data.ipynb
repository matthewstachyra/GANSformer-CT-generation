# %%
import os
import tarfile
import glob
import warnings

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pydicom

# %%
# !pip install seaborn pydicom
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/seaborn/
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl
# ...
#      |████████████████████████████████| 292 kB 1.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.0 MB 33.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.5 MB 17.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 39.3 MB 17.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 503 kB 21.6 MB/s eta 0:00:01
# ...

# %%
# Plot and Jupyter Config
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
warnings.filterwarnings('ignore')

# %%
img_test = 'img_data/train/00000/FLAIR/Image-2.dcm'

ds = pydicom.dcmread(img_test)

# %%
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.8.498.99403955578360448357552021011345435087
# (0008, 0050) Accession Number                    SH: '00000'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 103e) Series Description                  LO: 'FLAIR'
# (0010, 0010) Patient's Name                      PN: '00000'
# (0010, 0020) Patient ID                          LO: '00000'
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0050) Slice Thickness                     DS: '1.2'
# ...

# %%
flair_list = glob.glob('img_data/train/*/FLAIR/**.dcm')
t1w_list = glob.glob('img_data/train/*/T1w/**.dcm')
tw1ce_list = glob.glob('img_data/train/*/T1wCE/**.dcm')
tw2_list = glob.glob('img_data/train/*/T2w/**.dcm')

# %%
len(flair_list), len(t1w_list), len(tw1ce_list), len(tw2_list)
# Out:
# (74248, 77627, 96766, 100000)

# %%
for i in range(30):
    temp_ds = pydicom.dcmread(flair_list[i])
    plt.imshow(temp_ds.pixel_array, cmap=plt.cm.bone)
    plt.title(f'{i}')
    plt.show()

# %%
ds.pixel_array.shape
# Out:
# (512, 512)

# %%
temp_ds = pydicom.dcmread(flair_list[2])
plt.imshow(temp_ds.pixel_array, cmap=plt.cm.bone)
plt.title(f'{i}')
plt.show()
